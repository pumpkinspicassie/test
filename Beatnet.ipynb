# %%
pip install madmom
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# this file should be run in the virtual environment of beattrack

# %%
pip install Librosa
# Out:
# ...
#   Using cached librosa-0.10.2.post1-py3-none-any.whl.metadata (8.6 kB)
# ...
#   Using cached audioread-3.0.1-py3-none-any.whl.metadata (8.4 kB)
# ...
#   Using cached scikit_learn-1.5.0-cp311-cp311-macosx_10_9_x86_64.whl.metadata (11 kB)
# ...
#   Using cached joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# ...
#   Using cached numba-0.59.1-cp311-cp311-macosx_10_9_x86_64.whl.metadata (2.7 kB)
# ...
#   Using cached soundfile-0.12.1-py2.py3-none-macosx_10_9_x86_64.whl.metadata (14 kB)
# ...
#   Using cached pooch-1.8.1-py3-none-any.whl.metadata (9.5 kB)
# ...
#   Using cached soxr-0.3.7-cp311-cp311-macosx_10_9_x86_64.whl.metadata (5.5 kB)
# ...
#   Using cached lazy_loader-0.4-py3-none-any.whl.metadata (7.6 kB)
# ...
#   Using cached msgpack-1.0.8-cp311-cp311-macosx_10_9_x86_64.whl.metadata (9.1 kB)
# ...
#   Using cached llvmlite-0.42.0-cp311-cp311-macosx_10_9_x86_64.whl.metadata (4.8 kB)
# ...
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# ...
#   Using cached threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# ...

# %%
pip install pandas
# Out:
# ...
#   Using cached pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.6/12.6 MB 26.1 MB/s eta 0:00:0000:0100:01
# Using cached pytz-2024.1-py2.py3-none-any.whl (505 kB)
# Using cached tzdata-2024.1-py2.py3-none-any.whl (345 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np

# 原始代码
np.float = float    
np.int = int   # module 'numpy' has no attribute 'int'
np.object = object    # module 'numpy' has no attribute 'object'
np.bool = bool    # module 'numpy' has no attribute 'bool'

# %%
import pandas as pd

# %%
import madmom

# %%
import librosa

# %%
import pyaudio

# %%
from BeatNet.BeatNet import BeatNet

# %%
# 初始化 BeatNet 模型，禁用 plot 参数
estimator = BeatNet(3, mode='realtime', inference_model='PF', plot=[], thread=False)

# %%
# 处理音频数据，获取拍点和重拍位置
output = estimator.process('/Users/cassielu/Desktop/testdance/test1/gMH_sFM_c01_d24_mMH0_ch15.wav')

output
# Out:
# beat!
# *beat!
# beat!
# beat!
# *beat!
# beat!
# *beat!
# beat!
# beat!
# *beat!
# beat!
# *beat!
# beat!
# beat!
# beat!
# beat!
# beat!
# beat!
# beat!
# beat!
# beat!
# beat!
# beat!
# beat!
# beat!
# beat!
# *beat!
# beat!
# *beat!
# beat!
# beat!
# *beat!
# beat!
# beat!
# *beat!
# beat!
# *beat!
# beat!
# beat!
# beat!
# *beat!
# beat!
# beat!
# *beat!
# beat!
# beat!
# *beat!
# beat!
# beat!
# beat!
# *beat!
# beat!
# *beat!
# beat!
# *beat!
# beat!
# beat!
# beat!
# *beat!
# beat!
# beat!
# beat!
# *beat!
# beat!
# beat!
# beat!
# beat!
# *beat!
# beat!
# beat!
# *beat!
# beat!
# beat!
# *beat!
# beat!
# *beat!
# beat!
# beat!
# *beat!
# beat!
# *beat!
# beat!
# beat!
# *beat!
# beat!
# *beat!
# beat!
# beat!
# *beat!
# beat!
# beat!
# array([[ 1.08,  2.  ],
#        [ 1.86,  1.  ],
#        [ 2.22,  2.  ],
#        [ 2.6 ,  2.  ],
#        [ 3.02,  1.  ],
#        [ 3.76,  2.  ],
#        [ 4.16,  1.  ],
#        [ 4.54,  2.  ],
#        [ 5.28,  2.  ],
# ...

# %%
# 初始化 BeatNet 模型，禁用 plot 参数
estimator2 = BeatNet(1, mode='offline', inference_model='DBN', plot=[], thread=False)

# %%
# 处理音频数据，获取拍点和重拍位置
output2 = estimator2.process('/Users/cassielu/Desktop/testdance/test1/gMH_sFM_c01_d24_mMH0_ch15.wav')

output2
# Out:
# array([[2.000e-02, 2.000e+00],
#        [4.000e-01, 1.000e+00],
#        [7.400e-01, 2.000e+00],
#        [1.100e+00, 1.000e+00],
#        [1.480e+00, 2.000e+00],
#        [1.840e+00, 1.000e+00],
#        [2.220e+00, 2.000e+00],
#        [2.600e+00, 1.000e+00],
#        [2.980e+00, 2.000e+00],
#        [3.360e+00, 1.000e+00],
#        [3.740e+00, 2.000e+00],
#        [4.100e+00, 1.000e+00],
#        [4.480e+00, 2.000e+00],
#        [4.860e+00, 1.000e+00],
#        [5.240e+00, 2.000e+00],
#        [5.620e+00, 1.000e+00],
#        [6.000e+00, 2.000e+00],
#        [6.400e+00, 1.000e+00],
#        [6.780e+00, 2.000e+00],
#        [7.140e+00, 1.000e+00],
#        [7.520e+00, 2.000e+00],
#        [7.900e+00, 1.000e+00],
#        [8.280e+00, 2.000e+00],
#        [8.640e+00, 1.000e+00],
#        [8.980e+00, 2.000e+00],
#        [9.360e+00, 1.000e+00],
#        [9.720e+00, 2.000e+00],
#        [1.010e+01, 1.000e+00],
#        [1.048e+01, 2.000e+00],
#        [1.086e+01, 1.000e+00],
# ...
